# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

# %%
arr=np.array([10,20,30,40])

# %%
print(arr)
# Out:
# [10 20 30 40]

# %%
arr1=np.array([[10,20,30,40],[20,30,40,50]])

# %%
print(type(arr1))
print(arr1)
# Out:
# <class 'numpy.ndarray'>
# [[10 20 30 40]
#  [20 30 40 50]]

# %%
print(arr1[1,2:3])
print(arr1[0,2:3])
# Out:
# [40]
# [30]

# %%
arr2=np.array([[10,20,30,40],[20,30,40,50],[40,50,60,70]])

# %%
print(np.shape(arr2))
# Out:
# (3, 4)

# %%
print(np.size(arr2))
print(np.ndim(arr2))
print(arr.dtype)
# Out:
# 12
# 2
# int64

# %%
a=[12,14,121,41,23,13]
arr=np.array(a)
print(arr)
# Out:
# [ 12  14 121  41  23  13]

# %%
arr1=np.array([10,20,30,40])
arr2=np.array([30,50,30,60])
print(arr1+arr2)
print(arr1-arr2)+
print(arr1*arr2)
print(arr1/arr2)
# Out:
# [ 40  70  60 100]
# [-20 -30   0 -20]
# [ 300 1000  900 2400]
# [0.33333333 0.4        1.         0.66666667]

# %%
print(np.concatenate([arr1,arr2]))
# Out:
# [10 20 30 40 30 50 30 60]

# %%
arr1=np.array([[10,20,30,40],[30,50,40,70]])
print(arr1)
b=np.array_split(arr1,3)
print(b)
# Out:
# [[10 20 30 40]
#  [30 50 40 70]]
# [array([[10, 20, 30, 40]]), array([[30, 50, 40, 70]]), array([], shape=(0, 4), dtype=int64)]

# %%
print(np.append(arr1,[34,100]))
# Out:
# [ 10  20  30  40  30  50  40  70  34 100]
