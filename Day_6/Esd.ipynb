# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_excel("C:\Coding\Data-analytics-portfolio\Jupyter\Day_6\Datasets-main\ESD.xlsx")
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.loc[(df["Bonus %"] == 0), "GetBonus"]= "no bonus"
df.loc[(df["Bonus %"] > 0, "GetBonus")]= "bonus"
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df["Full Role"] = df["Full Name"] + " "+ df["Department"]
print(df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
a=pd.DataFrame(df)
print(a)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
def extract(value):
    return value[0:5]
a["Short_Name"]= a["Full Name"].map(extract)
print(a)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
data=pd.read_excel("C:\Coding\Data-analytics-portfolio\Jupyter\Day_6\Datasets-main\ESD.xlsx")

# %%
print(data.head(10))
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
gp = data.groupby("Department").agg({"Gender":"count"})
print(gp)
# Out:
#                  Gender
# Department
# Accounting           96
# Engineering         158
# Finance             120
# Human Resources     125
# IT                  241
# Marketing           120
# Sales               140

# %%
gp = data.groupby(["Department","Gender"]).agg({"Gender":"count"})
print(gp)
# Out:
#                         Gender
# Department      Gender
# Accounting      Female      53
#                 Male        43
# Engineering     Female      80
#                 Male        78
# Finance         Female      69
#                 Male        51
# Human Resources Female      64
#                 Male        61
# IT              Female     119
#                 Male       122
# Marketing       Female      57
#                 Male        63
# Sales           Female      76
#                 Male        64

# %%
gp1 = data.groupby("Country").agg({"Age":"mean"})
print(gp1)
# Out:
#                      Age
# Country
# Brazil         43.654676
# China          45.389908
# United States  44.197512

# %%
gp1 = data.groupby("Country").agg({"Annual Salary":"mean"})
print(gp1)
# Out:
#                Annual Salary
# Country
# Brazil         112324.834532
# China          113823.532110
# United States  113204.794712

# %%
gp1 = data.groupby("Country").agg({"Annual Salary":"max"})
print(gp1)
# Out:
#                Annual Salary
# Country
# Brazil                258426
# China                 257194
# United States         258498

# %%
gp1 = data.groupby(["Country","Gender"]).agg({"Annual Salary":"mean"})
print(gp1)
# Out:
#                       Annual Salary
# Country       Gender
# Brazil        Female  111343.733333
#               Male    113474.562500
# China         Female  113904.908257
#               Male    113742.155963
# United States Female  112012.964072
#               Male    114493.051780

# %%
gp1 = data.groupby(["Country","Gender"]).agg({"Annual Salary":"mean","Age":"min"})
print(gp1)
# Out:
#                       Annual Salary  Age
# Country       Gender
# Brazil        Female  111343.733333   25
#               Male    113474.562500   26
# China         Female  113904.908257   25
#               Male    113742.155963   25
# United States Female  112012.964072   25
#               Male    114493.051780   25

# %%
import pandas as pd

data1 = {"Emp Id":["E01", "E02","E03","E04","E05","E06"],
"Names": ["Ram","Shyam", "Rahul","Vishal","Ravi", "John"],
"Age": [34,56, 23,44, 32, 36]}

data2 = {"Emp Id":["E01", "E02","E03","E04","E05","E06"],
"Salary":[45000,56000, 34000, 30000, 50000, 62000]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

#print(df1)
print(df2)
print(df2)
# Out:
#   Emp Id  Salary
# 0    E01   45000
# 1    E02   56000
# 2    E03   34000
# 3    E04   30000
# 4    E05   50000
# 5    E06   62000
#   Emp Id  Salary
# 0    E01   45000
# 1    E02   56000
# 2    E03   34000
# 3    E04   30000
# 4    E05   50000
# 5    E06   62000

# %%
print(pd.merge(df1,df2,on = "Emp Id"))
# Out:
#   Emp Id   Names  Age  Salary
# 0    E01     Ram   34   45000
# 1    E02   Shyam   56   56000
# 2    E03   Rahul   23   34000
# 3    E04  Vishal   44   30000
# 4    E05    Ravi   32   50000
# 5    E06    John   36   62000

# %%
import pandas as pd

data1 = {"Emp Id":["E01", "E02","E03","E04","E05","E06"],
"Names": ["Ram","Shyam", "Rahul","Vishal", "Ravi", "John"],
"Age":[34,56,23,44, 32, 36]}

data2 = {"Emp Id":["E07", "E08","E09","E10","E11","E12"],
"Names": ["Shyam","Suraj","Sahul","Sukal","Kavi", "don"],
"Age":[34,56,23,44, 32, 36]}
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
print(pd.concat([df1,df2]))
# Out:
#   Emp Id   Names  Age
# 0    E01     Ram   34
# 1    E02   Shyam   56
# 2    E03   Rahul   23
# 3    E04  Vishal   44
# 4    E05    Ravi   32
# 5    E06    John   36
# 0    E07   Shyam   34
# 1    E08   Suraj   56
# 2    E09   Sahul   23
# 3    E10   Sukal   44
# 4    E11    Kavi   32
# 5    E12     don   36

# %%
dict = {"Fruits":["mango","apples","banana","papaya"],
"Price":[100,150,50,35],
"Quantity":[15,10,10,3]}

df1 = pd.DataFrame(dict)
print (df1)

df2 = df1.copy()
# Out:
#    Fruits  Price  Quantity
# 0   mango    100        15
# 1  apples    150        10
# 2  banana     50        10
# 3  papaya     35         3
